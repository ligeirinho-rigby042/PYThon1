# %% [markdown]
# <a href="https://colab.research.google.com/github/ligeirinho-rigby042/PYThon1/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AULA** **1** 🕷 🕸 👻
# <img src="https://hqpop.com.br/wp-content/uploads/2025/02/hqpop_richard_0502.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1200px; height: 314px; margin: 0px; width: 558px;" alt="Novo Homem-Aranha é mais espetacular que Peter Parker - HQPOP" jsname="kn3ccd">

# %%
ano = "IX"
print(ano, "competição de programação Start")
# Out:
# IX competição de programação Start

# %% [markdown]
# # **AULA 2**  ⏰ ✈ ⬛

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do ana são {pontos_ana}")
print(f"Os pontos totais do ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do ana são 46
# Os pontos totais do ana e Rodrigo são 70

# %% [markdown]
# # **AULA 3** ⚾ ⛹ ✅

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2999363842.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3 figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# # **AULA** **4** ⌛ 🔥 🏴

# %%
def tabuada(numero):
   for contador in range(1, 11): # Gera números de 1 a 10
      print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10

# %% [markdown]
# # **AULA 5 ♣: ➗ ⛹ DIVISÃO**

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua divisao: "))
tabuada(numero)

# %% [markdown]
# # **AULA 6 ⛹ ⛹ ♣ CHATBOT**

# %%
print("Olá sou seu assistente virtual")
nome = input("Digite seu nome: ")
print(f"Olá {nome}, em que posso ajudar")
resposta = input("Você deseja falar sobre Python,Javascript ou Matemática: ").lower()
if resposta == "python":
  print(f"Ótimo, {nome} vamos falar sobre Python! \n Python é uma linguagem poderosa e versátil, perfeita tanto para iniciantes quanto para desenvolvedores experientes, permitindo a criação de tudo, desde scripts simples até sistemas complexos de inteligência artificial.")
elif resposta == "javascript":
  print(f"Ótimo, {nome} vamos falar sobre Javascript! \n JavaScript é uma linguagem essencial para o desenvolvimento web, permitindo que criemos experiências interativas, dinâmicas e responsivas que funcionam diretamente no navegador.")
elif resposta == "matemática":
  print(f"Ótimo, {nome} vamos falar sobre Matemática! \n A matemática é a linguagem universal que descreve a estrutura e os padrões do universo, transformando ideias abstratas em soluções práticas para os desafios do mundo real.")
  else:
  print(f"Que pena, {nome} não sei falar sobre esse assunto,!")

# %% [markdown]
# # **AULA 7 👲 🤡 🛶 LISTAS**

# %%
dica_do_dia = [
    " 🤓 Comece onde você está, use o que você tem e faça o que você pode",
    " 🫡 A persistência realiza o impossível.",
    " 😏 Acredite em si mesmo e todo o resto virá naturalmente",
    " 🫠 Grandes conquistas começam com pequenas atitudes todos os dias",
    " ☺️ Transforme seus obstáculos em degraus para o sucesso",
    " 🤨 Descanse o corpo, mas nunca a alma sonhadora.",
    " 🤌🏿 Gratidão pelo que foi, fé no que virá.",
    ]

while True:
    pedido = input("digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

    if pedido == "dica":
        dica = random.choice(dica_do_dia)
        print(f"dica: {dica} \n")
    elif pedido == "sair":
        print("Saindo do programa. Até logo!")
        break
    else:
        print("comando invalido. tente novamente. \n")
